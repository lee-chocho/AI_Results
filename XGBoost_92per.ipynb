# %% [markdown]
# <a href="https://colab.research.google.com/github/lee-chocho/AI_Results/blob/main/XGBoost_92per.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ###**No augmentation**

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# * round별로 validation curve의 향상이 없고, training curve는 1.00이 된다.
#
#
# * Accuracy: 0.7787114845938375
# * F1 Score: 0.7666884226644323
# * Precision: 0.7823856690846234
# * Recall: 0.7787114845938375

# %% [markdown]
# ###**x3 augmentation**

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# * 증강을 안했을 경우보다 learning curve가 비교적 정상적으로 보인다.
#
#
# * Accuracy: 0.8982259570494865
# * F1 Score: 0.8965596965591444
# * Precision: 0.9009439001219118
# * Recall: 0.8982259570494865

# %% [markdown]
# ###**x5 augmentation**

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# * 증강을 안했을 경우보다 learning curve가 비교적 정상적으로 보인다.
#
#
# * Accuracy: 0.9254484304932735
# * F1 Score: 0.9241436413033716
# * Precision: 0.9287885585054558
# * Recall: 0.9254484304932735
