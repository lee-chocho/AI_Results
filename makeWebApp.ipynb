# %% [markdown]
# ## Streamlit 라이브러리를 통한 AI WebApp 제작

# %% [markdown]
# ### Classification of current immune status

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ### Prediction of blood test item values

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)
