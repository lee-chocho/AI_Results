# %% [markdown]
# ### **Streamlit 라이브러리를 통한 AI WebApp 제작**

# %% [markdown]
# ### **Welcome page**

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ### **Statistics page**

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ### **Prediction page**

# %% [markdown]
# ##### 선택한 환자의 기록이 한건만 존재할 경우 "Insufficient data available for the selected patient" 경고문구 출력

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ##### 선택한 환자의 기록이 두건 이상 존재할 경우 값 예측 후 암 면역 상태 출력

# %% [markdown]
# ![image.png](data:image/png;base64,...)
